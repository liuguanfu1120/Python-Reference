# %%
# -*- coding: utf-8 -*-
"""
@Author: Guanfu Liu
To plot the figure of z versus t
"""

import matplotlib.pyplot as plt
from astropy.cosmology import FlatLambdaCDM
import astropy.units as u
import numpy as np
from astropy.cosmology import z_at_value
# %matplotlib notebook


cosmo = FlatLambdaCDM(H0=70*u.km/u.s/u.Mpc, Om0=0.3)
ages = np.linspace(0.2,13,100)*u.Gyr
z = np.array([z_at_value(cosmo.age, age) for age in ages])
fig, ax = plt.subplots(nrows=1,ncols=1,dpi=100)
ax.plot(z,13-ages.value)
ax.set_xlabel('z(redshift)')
ax.set_ylabel('t(Gyr)')
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
18*np.pi**2-82*0.7-39*0.7**2
# Out:
# 101.14287921960845

# %%
ages
# Out:
# <Quantity [ 0.2       ,  0.32929293,  0.45858586,  0.58787879,  0.71717172,
#             0.84646465,  0.97575758,  1.10505051,  1.23434343,  1.36363636,
#             1.49292929,  1.62222222,  1.75151515,  1.88080808,  2.01010101,
#             2.13939394,  2.26868687,  2.3979798 ,  2.52727273,  2.65656566,
#             2.78585859,  2.91515152,  3.04444444,  3.17373737,  3.3030303 ,
#             3.43232323,  3.56161616,  3.69090909,  3.82020202,  3.94949495,
#             4.07878788,  4.20808081,  4.33737374,  4.46666667,  4.5959596 ,
#             4.72525253,  4.85454545,  4.98383838,  5.11313131,  5.24242424,
#             5.37171717,  5.5010101 ,  5.63030303,  5.75959596,  5.88888889,
#             6.01818182,  6.14747475,  6.27676768,  6.40606061,  6.53535354,
#             6.66464646,  6.79393939,  6.92323232,  7.05252525,  7.18181818,
#             7.31111111,  7.44040404,  7.56969697,  7.6989899 ,  7.82828283,
# ...

# %%
ages.value
# Out:
# array([ 0.2       ,  0.32929293,  0.45858586,  0.58787879,  0.71717172,
#         0.84646465,  0.97575758,  1.10505051,  1.23434343,  1.36363636,
#         1.49292929,  1.62222222,  1.75151515,  1.88080808,  2.01010101,
#         2.13939394,  2.26868687,  2.3979798 ,  2.52727273,  2.65656566,
#         2.78585859,  2.91515152,  3.04444444,  3.17373737,  3.3030303 ,
#         3.43232323,  3.56161616,  3.69090909,  3.82020202,  3.94949495,
#         4.07878788,  4.20808081,  4.33737374,  4.46666667,  4.5959596 ,
#         4.72525253,  4.85454545,  4.98383838,  5.11313131,  5.24242424,
#         5.37171717,  5.5010101 ,  5.63030303,  5.75959596,  5.88888889,
#         6.01818182,  6.14747475,  6.27676768,  6.40606061,  6.53535354,
#         6.66464646,  6.79393939,  6.92323232,  7.05252525,  7.18181818,
#         7.31111111,  7.44040404,  7.56969697,  7.6989899 ,  7.82828283,
#         7.95757576,  8.08686869,  8.21616162,  8.34545455,  8.47474747,
# ...

# %%
z
# Out:
# array([18.33283412, 12.86438458, 10.11651738,  8.41899654,  7.24863371,
#         6.38435978,  5.71530457,  5.17922751,  4.73826412,  4.36794563,
#         4.05169699,  3.7778577 ,  3.53796555,  3.32571796,  3.13631603,
#         2.96603583,  2.81193966,  2.67167619,  2.54333931,  2.42536603,
#         2.31646161,  2.21554358,  2.12169936,  2.03415372,  1.95224353,
#         1.87539786,  1.8031224 ,  1.73498668,  1.67061406,  1.60967339,
#         1.55187226,  1.49695144,  1.44468018,  1.39485244,  1.34728349,
#         1.3018073 ,  1.25827414,  1.21654866,  1.17650806,  1.13804079,
#         1.10104517,  1.06542834,  1.03110536,  0.99799827,  0.96603546,
#         0.93515101,  0.90528409,  0.87637854,  0.84838236,  0.82124734,
#         0.79492876,  0.76938503,  0.74457743,  0.72046988,  0.69702868,
#         0.67422236,  0.65202145,  0.63039836,  0.60932722,  0.58878373,
#         0.56874506,  0.54918973,  0.53009751,  0.51144935,  0.49322727,
# ...

# %%
cosmo.H0
# Out:
# <Quantity 70. km / (Mpc s)>
